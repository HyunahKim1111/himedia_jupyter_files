# %%
import os
import sys
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url = 'http://apis.data.go.kr/B552735/workspaceErumService/getAreaCenterList'

# %%
s_key = 'IO/EdnZ45auz8e6mcFKmXH/ZDn7lirSzzkWblTjoMfS331/hBMrvQ5v3KLTs6yfo1gM4Kdp0kRJaYqcRbkvt5w=='

# %%
area = '서울'

# %%
payload = dict(ServiceKey = s_key, area = '서울', dataType='json')

# %%
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\envs\testenv\lib\site-packages\urllib3\response.py:444, in HTTPResponse._error_catcher(self)
#     443 try:
# --> 444     yield
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
#
# File ~\anaconda3\envs\testenv\lib\site-packages\urllib3\response.py:831, in HTTPResponse.read_chunked(self, amt, decode_content)
#     830     break
# --> 831 chunk = self._handle_chunk(amt)
#     832 decoded = self._decode(
#     833     chunk, decode_content=decode_content, flush_decoder=False
#     834 )
#
# File ~\anaconda3\envs\testenv\lib\site-packages\urllib3\response.py:784, in HTTPResponse._handle_chunk(self, amt)
#     783 else:  # amt > self.chunk_left
# --> 784     returned_chunk = self._fp._safe_read(self.chunk_left)
#     785     self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#
# File ~\anaconda3\envs\testenv\lib\http\client.py:613, in HTTPResponse._safe_read(self, amt)
#     607 """Read the number of bytes requested.
#     608
#     609 This function should be used when <amt> bytes "should" be present for
#     610 reading. If the bytes are truly not available (due to EOF), then the
#     611 IncompleteRead exception can be used to detect the problem.
#     612 """
# --> 613 data = self.fp.read(amt)
#     614 if len(data) < amt:
#
# File ~\anaconda3\envs\testenv\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# ConnectionResetError: [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\anaconda3\envs\testenv\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     815 try:
# --> 816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
#
# File ~\anaconda3\envs\testenv\lib\site-packages\urllib3\response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#
# File ~\anaconda3\envs\testenv\lib\site-packages\urllib3\response.py:857, in HTTPResponse.read_chunked(self, amt, decode_content)
#     856 if self._original_response:
# --> 857     self._original_response.close()
#
# File ~\anaconda3\envs\testenv\lib\contextlib.py:131, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     130 try:
# --> 131     self.gen.throw(type, value, traceback)
#     132 except StopIteration as exc:
#     133     # Suppress StopIteration *unless* it's the same exception that
#     134     # was passed to throw().  This prevents a StopIteration
#     135     # raised inside the "with" statement from being suppressed.
#
# File ~\anaconda3\envs\testenv\lib\site-packages\urllib3\response.py:461, in HTTPResponse._error_catcher(self)
#     459 except (HTTPException, SocketError) as e:
#     460     # This includes IncompleteRead.
# --> 461     raise ProtocolError("Connection broken: %r" % e, e)
#     463 # If no exception is thrown, we should avoid cleaning up
#     464 # unnecessarily.
#
# ProtocolError: ("Connection broken: ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None)", ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 r = requests.get(url, params=payload)
#       2 print(r.url)
#       3 print(r.status_code)
#
# File ~\anaconda3\envs\testenv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\envs\testenv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\testenv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\testenv\lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~\anaconda3\envs\testenv\lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~\anaconda3\envs\testenv\lib\site-packages\requests\models.py:818, in Response.iter_content.<locals>.generate()
#     816     yield from self.raw.stream(chunk_size, decode_content=True)
#     817 except ProtocolError as e:
# --> 818     raise ChunkedEncodingError(e)
#     819 except DecodeError as e:
#     820     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None)", ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))

# %%
r.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
r.json()

# %%
r.text()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 r.text()
#
# TypeError: 'str' object is not callable

# %%
response = r.json

# %%
response
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><items><item cnterId="352"><cnterNm>(사)한국여성벤처협회 여성특화 1인창조기업지원센터</cnterNm><cnterTyNm>1인창조기업지원센터</cnterTyNm><buldId>352</buldId><buldNm>한국여성벤처협회</buldNm><zip>06247</zip><adr>서울특별시 강남구 역삼로 165</adr><telnm>02-3440-7467</telnm><fxnum>02-3440-7474</fxnum><homepage>http://www.kovwa.or.kr/</homepage><cnterIntrcn>&lt;p style="line-height: 33.6px; font-family: \'Nanum Gothic\'; font-size: 14pt; margin-top: 0px; margin-bottom: 0px;"&gt;\n한국여성벤처협회는 여성벤처기업의 권익보호 및 성장기반 마련하고자 1998년 중소기업청에서 허가를 받았습니다. \n회원사는 천여개사이며 현재 지속적인 회원 증대가 이루어지고 있습니다. \n업종은 IT/소프트웨어, 지식서비스 등 유망분야 여성벤처기업이 45%수준입니다. \n여성벤처창업 케어 프로그램 및 선도벤처연계 창업사업 등 다년간의 창업사업 수행을 통해 경험과 노하우를 가지고 있습니다. \n유망한 여성 1인 창조기업 발굴, 교육과 멘토링을 통한 사업화 역량 강화, 판로지원 프로그램을 통해1인 창조기업의 매출 및 고용 확대로 여성 1인 창조기업 허브 센터로 자리매김하고자 합니다.\n&lt;/p&gt;</cnterIntrcn><lo>127.037158972950780</lo><la>37.495406920451366</la><spceCnt>20</spceCnt></item><item cnterId="306"><cnterNm>(인공지능 특화) 하우투비즈센터</cnterNm><cnterTyNm>1인창조기업지원센터</cnterTyNm><buldId>306</buldId><buldNm>아이비피아빌딩</buldNm><zip>150871</zip><adr>서울특별시 영등포구 국회대로72길 4</adr><telnm>1644-4812</telnm><fxnum>0505-718-9046</fxnum><homepage>https://howtobizcenter.com</homepage><cnterIntrcn>&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;하우투비즈는 아직 가고자 하는 길이 먼 작은 기업입니다.&amp;nbsp;&lt;/span&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;하지만 하우투비즈는 당신의 사업 성공을 돕기 위한 열정으로 가득 차있습니다.&amp;nbsp;&lt;/span&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;하우투비즈가 운영하는 비즈니스센터는 다른 비즈니스센터와 달라야 합니다.&amp;nbsp;&lt;/span&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;훌륭한 사무공간도 중요하지만 Start-up의 안정적인 사업 성장을 지원하기 위해서는 그보다 더 많은 것을 고려해야 하기 때문입니다.&amp;nbsp;&lt;/span&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;우리는 더 많은 경험을 통해 더 효과적인 지원 정책을 찾고 계속해서 반영할 것입니다.&lt;/span&gt;&lt;/p&gt;&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&amp;nbsp;&lt;/p&gt;&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&amp;nbsp;&lt;/p&gt;</cnterIntrcn><lo>126.919960000000000</lo><la>37.530308000000000</la><spceCnt>20</spceCnt></item><item cnterId="402"><cnterNm>(재)여성기업종합지원센터 서울센터</cnterNm><cnterTyNm>여성기업종합지원센터</cnterTyNm><buldId>483</buldId><buldNm>일신빌딩</buldNm><zip>04174</zip><adr>서울 마포구 마포대로 38 (도화동, 일신빌딩)</adr><telnm>02-713-0280</telnm><fxnum>02-713-0270</fxnum><homepage>http://www.wbiz.or.kr/</homepage><cnterIntrcn>&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&lt;span style="font-size: 11pt; font-family: \'Nanum Gothic\'; line-height: 26.4px; margin-top: 0px; margin-bottom: 0px;"&gt;여성기업종합지원센터 서울센터는 서울소재 예비 여성창업인 또는 창업초기 여성기업인(사업자등록일로부터 3년 미만)들의 초기 창업기반확보를 위한 창업보육센터를 운영하고 있습니다.&amp;nbsp;&lt;/span&gt;&lt;/p&gt;</cnterIntrcn><lo>126.946640000000000</lo><la>37.539394000000000</la><spceCnt>16</spceCnt></item><item cnterId="396"><cnterNm>(재)여성기업종합지원센터 중앙센터</cnterNm><cnterTyNm>여성기업종합지원센터</cnterTyNm><buldId>480</buldId><buldNm>(재)여성기업종합지원센터 중앙센터</buldNm><zip>06224</zip><adr>서울 강남구 역삼로 221 (역삼동, 한국여성경제인협회)</adr><telnm>02-369-0943</telnm><fxnum>02-555-8616</fxnum><homepage>http://www.wbiz.or.kr/</homepage><cnterIntrcn>&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&lt;span style="font-size: 11pt; font-family: \'Nanum Gothic\'; line-height: 26.4px; margin-top: 0px ...

# %%
response = r.text

#data2 = json.loads(data)

# %%
response
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><items><item cnterId="352"><cnterNm>(사)한국여성벤처협회 여성특화 1인창조기업지원센터</cnterNm><cnterTyNm>1인창조기업지원센터</cnterTyNm><buldId>352</buldId><buldNm>한국여성벤처협회</buldNm><zip>06247</zip><adr>서울특별시 강남구 역삼로 165</adr><telnm>02-3440-7467</telnm><fxnum>02-3440-7474</fxnum><homepage>http://www.kovwa.or.kr/</homepage><cnterIntrcn>&lt;p style="line-height: 33.6px; font-family: \'Nanum Gothic\'; font-size: 14pt; margin-top: 0px; margin-bottom: 0px;"&gt;\n한국여성벤처협회는 여성벤처기업의 권익보호 및 성장기반 마련하고자 1998년 중소기업청에서 허가를 받았습니다. \n회원사는 천여개사이며 현재 지속적인 회원 증대가 이루어지고 있습니다. \n업종은 IT/소프트웨어, 지식서비스 등 유망분야 여성벤처기업이 45%수준입니다. \n여성벤처창업 케어 프로그램 및 선도벤처연계 창업사업 등 다년간의 창업사업 수행을 통해 경험과 노하우를 가지고 있습니다. \n유망한 여성 1인 창조기업 발굴, 교육과 멘토링을 통한 사업화 역량 강화, 판로지원 프로그램을 통해1인 창조기업의 매출 및 고용 확대로 여성 1인 창조기업 허브 센터로 자리매김하고자 합니다.\n&lt;/p&gt;</cnterIntrcn><lo>127.037158972950780</lo><la>37.495406920451366</la><spceCnt>20</spceCnt></item><item cnterId="306"><cnterNm>(인공지능 특화) 하우투비즈센터</cnterNm><cnterTyNm>1인창조기업지원센터</cnterTyNm><buldId>306</buldId><buldNm>아이비피아빌딩</buldNm><zip>150871</zip><adr>서울특별시 영등포구 국회대로72길 4</adr><telnm>1644-4812</telnm><fxnum>0505-718-9046</fxnum><homepage>https://howtobizcenter.com</homepage><cnterIntrcn>&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;하우투비즈는 아직 가고자 하는 길이 먼 작은 기업입니다.&amp;nbsp;&lt;/span&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;하지만 하우투비즈는 당신의 사업 성공을 돕기 위한 열정으로 가득 차있습니다.&amp;nbsp;&lt;/span&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;하우투비즈가 운영하는 비즈니스센터는 다른 비즈니스센터와 달라야 합니다.&amp;nbsp;&lt;/span&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;훌륭한 사무공간도 중요하지만 Start-up의 안정적인 사업 성장을 지원하기 위해서는 그보다 더 많은 것을 고려해야 하기 때문입니다.&amp;nbsp;&lt;/span&gt;&lt;span style="font-size: 14pt; font-family: \'Nanum Gothic\'; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;우리는 더 많은 경험을 통해 더 효과적인 지원 정책을 찾고 계속해서 반영할 것입니다.&lt;/span&gt;&lt;/p&gt;&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&amp;nbsp;&lt;/p&gt;&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&amp;nbsp;&lt;/p&gt;</cnterIntrcn><lo>126.919960000000000</lo><la>37.530308000000000</la><spceCnt>20</spceCnt></item><item cnterId="402"><cnterNm>(재)여성기업종합지원센터 서울센터</cnterNm><cnterTyNm>여성기업종합지원센터</cnterTyNm><buldId>483</buldId><buldNm>일신빌딩</buldNm><zip>04174</zip><adr>서울 마포구 마포대로 38 (도화동, 일신빌딩)</adr><telnm>02-713-0280</telnm><fxnum>02-713-0270</fxnum><homepage>http://www.wbiz.or.kr/</homepage><cnterIntrcn>&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&lt;span style="font-size: 11pt; font-family: \'Nanum Gothic\'; line-height: 26.4px; margin-top: 0px; margin-bottom: 0px;"&gt;여성기업종합지원센터 서울센터는 서울소재 예비 여성창업인 또는 창업초기 여성기업인(사업자등록일로부터 3년 미만)들의 초기 창업기반확보를 위한 창업보육센터를 운영하고 있습니다.&amp;nbsp;&lt;/span&gt;&lt;/p&gt;</cnterIntrcn><lo>126.946640000000000</lo><la>37.539394000000000</la><spceCnt>16</spceCnt></item><item cnterId="396"><cnterNm>(재)여성기업종합지원센터 중앙센터</cnterNm><cnterTyNm>여성기업종합지원센터</cnterTyNm><buldId>480</buldId><buldNm>(재)여성기업종합지원센터 중앙센터</buldNm><zip>06224</zip><adr>서울 강남구 역삼로 221 (역삼동, 한국여성경제인협회)</adr><telnm>02-369-0943</telnm><fxnum>02-555-8616</fxnum><homepage>http://www.wbiz.or.kr/</homepage><cnterIntrcn>&lt;p style="font-family: \'Nanum Gothic\'; font-size: 14pt; line-height: 33.6px; margin-top: 0px; margin-bottom: 0px;"&gt;&lt;span style="font-size: 11pt; font-family: \'Nanum Gothic\'; line-height: 26.4px; margin-top: 0px ...
