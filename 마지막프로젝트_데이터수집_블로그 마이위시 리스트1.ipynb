# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = 'https://lovekorevent.com/%EC%83%88%ED%95%B4-%EB%AA%A9%ED%91%9C-%EB%A6%AC%EC%8A%A4%ED%8A%B8-100%EA%B0%80%EC%A7%80-%EC%98%88%EC%8B%9C-%EB%B2%84%ED%82%B7%EB%A6%AC%EC%8A%A4%ED%8A%B8-%EC%B6%94%EC%B2%9C-%EC%96%91%EC%8B%9D/'

# %%
r = requests.get(url)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="ko-KR">\n<head>\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="http://gmpg.org/xfn/11">\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v21.7 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>새해 목표 리스트 100가지 예시 (버킷리스트 추천 양식)</title>\n\t<meta name="description" content="새해 목표 리스트 ※ 개인 성장/ 건강 및 웰빙/ 직업 및 경력/ 관계 및 사회적 목표/ 취미 및 여가/ 재정 및 경제적 목표/ 개인적인 창의성과 표현/ 기술 및 전문성 개발/ 자아 발견 및 정신적 성장/ 환경 및 지속 가능성" />\n\t<link rel="canonical" href="https://lovekorevent.com/새해-목표-리스트-100가지-예시-버킷리스트-추천-양식/" />\n\t<meta property="og:locale" content="ko_KR" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="새해 목표 리스트 100가지 예시 (버킷리스트 추천 양식)" />\n\t<meta property="og:description" content="새해 목표 리스트 ※ 개인 성장/ 건강 및 웰빙/ 직업 및 경력/ 관계 및 사회적 목표/ 취
# ...

# %%
soup = bs(r.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <!-- This site is optimized with the Yoast SEO plugin v21.7 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>새해 목표 리스트 100가지 예시 (버킷리스트 추천 양식)</title>
# <meta content="새해 목표 리스트 ※ 개인 성장/ 건강 및 웰빙/ 직업 및 경력/ 관계 및 사회적 목표/ 취미 및 여가/ 재정 및 경제적 목표/ 개인적인 창의성과 표현/ 기술 및 전문성 개발/ 자아 발견 및 정신적 성장/ 환경 및 지속 가능성" name="description"/>
# <link href="https://lovekorevent.com/새해-목표-리스트-100가지-예시-버킷리스트-추천-양식/" rel="canonical"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="새해 목표 리스트 100가지 예시 (버킷리스트 추천 양식)" property="og:title"/>
# ...

# %%
soup.select('#post-2570 p')
# Out:
# [<p class="ez-toc-title">목차</p>,
#  <p>새해가 되면, 많은 사람들이 새로운 목표와 다짐을 세웁니다. 이는 새로운 한 해를 의미 있게 시작하는 방법 중 하나입니다. 이 글에서는 다양한 분야에서 영감을 얻을 수 있는 ‘새해 목표 리스트 100가지’를 제시하고자 합니다. 이 리스트는 개인적인 성장, 건강, 직업, 관계, 취미 등 다양한 분야를 아우릅니다.</p>,
#  <p>1. 매일 10분씩 명상하기 </p>,
#  <p>2. 새로운 언어 배우기 시작하기 </p>,
#  <p>3. 매주 한 권의 책 읽기 </p>,
#  <p>4. 일기 쓰기 습관 들이기 </p>,
#  <p>5. 공개 연설 기술 개선하기 </p>,
#  <p>6. 새로운 취미 시작하기 </p>,
#  <p>7. 자기계발 세미나 참여하기 </p>,
#  <p>8. 시간 관리 기술 향상시키기 </p>,
#  <p>9. 긍정적인 사고방식 유지하기 </p>,
#  <p>10. 매일 감사 일기 작성하기</p>,
#  <p>11. 주 3회 이상 운동하기 </p>,
#  <p>12. 건강한 식습관 유지하기 </p>,
#  <p>13. 매일 8시간 수면 취하기 </p>,
#  <p>14. 스트레스 관리 방법 배우기 </p>,
#  <p>15. 요가나 명상 클래스 등록하기 </p>,
#  <p>16. 정기적으로 건강 검진 받기 </p>,
#  <p>17. 물 많이 마시기 </p>,
#  <p>18. 금연 또는 금주하기 </p>,
#  <p>19. 정기적인 스트레칭 습관 만들기 </p>,
#  <p>20. 건강한 간식 선택하기</p>,
#  <p>21. 전문성 강화를 위한 추가 교육 받기 </p>,
#  <p>22. 효과적인 네트워킹 습관 만들기 </p>,
#  <p>23. 직장 내에서 리더십 역량 강화하기 </p>,
#  <p>24. 새로운 프로젝트나 업무에 도전하기 </p>,
#  <p>25. 직장 내 워크숍이나 팀 빌딩 참여하기 </p>,
# ...

# %%
#post-2570 > div > p:nth-child(5) ~ #post-2570 > div > p:nth-child(135)

# %%
soup.select_one('#post-2570 > div > p:nth-child(16)').text
# Out:
# '11. 주 3회 이상 운동하기 '

# %%
soup.select_one('#post-2570 p').text
# Out:
# '목차'

# %%
# chatGPT 도움을 받아 내가 다시 짜기
wishlist = []
for i in range(5, 136):
    selector = f"#post-2570 > div > p:nth-child({i})"
    wish = soup.select_one(selector)
    if wish:
        wishlist.append({'위시목록':wish.text})
        print(wish.text)
# Out:
# 1. 매일 10분씩 명상하기
# 2. 새로운 언어 배우기 시작하기
# 3. 매주 한 권의 책 읽기
# 4. 일기 쓰기 습관 들이기
# 5. 공개 연설 기술 개선하기
# 6. 새로운 취미 시작하기
# 7. 자기계발 세미나 참여하기
# 8. 시간 관리 기술 향상시키기
# 9. 긍정적인 사고방식 유지하기
# 10. 매일 감사 일기 작성하기
# 11. 주 3회 이상 운동하기
# 12. 건강한 식습관 유지하기
# 13. 매일 8시간 수면 취하기
# 14. 스트레스 관리 방법 배우기
# 15. 요가나 명상 클래스 등록하기
# 16. 정기적으로 건강 검진 받기
# 17. 물 많이 마시기
# 18. 금연 또는 금주하기
# 19. 정기적인 스트레칭 습관 만들기
# 20. 건강한 간식 선택하기
# 21. 전문성 강화를 위한 추가 교육 받기
# 22. 효과적인 네트워킹 습관 만들기
# 23. 직장 내에서 리더십 역량 강화하기
# 24. 새로운 프로젝트나 업무에 도전하기
# 25. 직장 내 워크숍이나 팀 빌딩 참여하기
# 26. 시간 내서 직무 관련 서적 읽기
# 27. 멘토 찾기 또는 멘토 되기
# 28. 커리어 관련 목표 설정하고 달성하기
# 29. 효율적인 업무 방식 찾기
# 30. 직장 내 긍정적인 관계 구축하기
# 31. 가족과 더 많은 시간 보내기
# 32. 친구들과 정기적으로 만나기
# 33. 새로운 사람들과 친구 되기
# 34. 봉사 활동 참여하기
# 35. 지역 사회 이벤트에 참여하기
# 36. 관계 속에서 솔직하고 개방적이 되기
# 37. 갈등 해결 기술 향상시키기
# 38. 소셜 미디어 사용 줄이기
# 39. 친절하고 배려심 있는 사람 되기
# 40. 감사의 마음을 자주 표현하기
# 41. 여행 계획 세우기
# 42. 새로운 요리 레시피 시도하기
# 43. 사진 찍기
# 44. 정원 가꾸기
# 45. 음악 연주나 노래 배우기
# 46. 그림이나 공예 활동하기
# 47. 문화 행사나 전시회 방문하기
# 48. 캠핑이나 등산하기
# ...

# %%
# 내가 짠 거
# wishlist = []
# for i in range(5, 136):
#     selector = f'#post-2570 > div > p:nth-child({i}'
#     wish = wish.select_one(f'#post-2570 > div > p:nth-child({i})').text
#     wishlist.append(wish)
#     print(wish)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 4
#       2 for i in range(5, 136):
#       3     selector = f'#post-2570 > div > p:nth-child({i}'
# ----> 4     wish = wish.select_one(f'#post-2570 > div > p:nth-child({i})').text
#       5     wishlist.append(wish)
#       6     print(wish)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
print(len(wishlist))
# Out:
# 100

# %%
import pandas as pd

# %%
wishlist_df = pd.DataFrame(wishlist)

# %%
wishlist_df
# Out:
#                          위시목록
# 0            1. 매일 10분씩 명상하기
# 1         2. 새로운 언어 배우기 시작하기
# 2            3. 매주 한 권의 책 읽기
# 3            4. 일기 쓰기 습관 들이기
# 4           5. 공개 연설 기술 개선하기
# ..                        ...
# 95  96. 대중교통 또는 자전거 이용 증가시키기
# 96         97. 환경 관련 교육 참여하기
# 97         98. 가정 내 물 사용 줄이기
# 98        99. 환경 보호 캠페인 참여하기
# 99   100. 제로 웨이스트 라이프스타일 추구하기
#
# [100 rows x 1 columns]

# %%
wishlist_df.to_csv("./data/wish_list1.csv", index=False)

# %%
data = pd.read_csv("./data/wish_list1.csv")

# %%
data
# Out:
#                          위시목록
# 0            1. 매일 10분씩 명상하기
# 1         2. 새로운 언어 배우기 시작하기
# 2            3. 매주 한 권의 책 읽기
# 3            4. 일기 쓰기 습관 들이기
# 4           5. 공개 연설 기술 개선하기
# ..                        ...
# 95  96. 대중교통 또는 자전거 이용 증가시키기
# 96         97. 환경 관련 교육 참여하기
# 97         98. 가정 내 물 사용 줄이기
# 98        99. 환경 보호 캠페인 참여하기
# 99   100. 제로 웨이스트 라이프스타일 추구하기
#
# [100 rows x 1 columns]

# %% [markdown]
# 두 번째 블로그 가자!

# %%
url = 'https://seonye.tistory.com/220'

# %%
r = requests.get(url)

# %%
r.text
# Out:
# '<!doctype html>\n<html lang="ko">\n                                                                                <head>\n                <script type="text/javascript">if (!window.T) { window.T = {} }\nwindow.T.config = {"TOP_SSL_URL":"https://www.tistory.com","PREVIEW":false,"ROLE":"guest","PREV_PAGE":"","NEXT_PAGE":"","BLOG":{"id":3141102,"name":"seonye","title":"30대 싱글 라이프    &lt; 모모몬의 숲 &gt;","isDormancy":false,"nickName":"모모몬","status":"open"},"NEED_COMMENT_LOGIN":true,"COMMENT_LOGIN_CONFIRM_MESSAGE":"이 블로그는 로그인한 사용자에게만 댓글 작성을 허용했습니다. 지금 로그인하시겠습니까?","LOGIN_URL":"https://www.tistory.com/auth/login/?redirectUrl=https://seonye.tistory.com/220","DEFAULT_URL":"https://seonye.tistory.com","USER":{"name":null,"homepage":null,"id":0,"profileImage":null},"SUBSCRIPTION":{"status":"none","isConnected":false,"isPending":false,"isWait":false,"isProcessing":false,"isNone":true},"IS_LOGIN":false,"HAS_BLOG":false,"IS_SUPPORT":false,"TOP_URL":"http://www.tistory.com","JOIN_URL":"https://www.t
# ...

# %%
soup = bs(r.text, 'lxml')

# %%
#content > div > div.entry-content > div.contents_style > p:nth-child(7) 
#content > div > div.entry-content > div.contents_style > p:nth-child(89)

# %%
soup.select('#content p')
# Out:
# [<p data-ke-size="size18">2020년이 한 달도 남지 않았다. 이 글을 통해 작년에 세웠던 2020년 계획을 돌아보고 다가오는 2021년 새해 계획과 목표를 세워보려고 한다. 그리고 더 나아가 지난 20대를 되새기고 멋진 30대를 꿈꾸는 나의 새로운 버킷리스트도 작성해보려고 한다. 인터넷에 떠도는 뻔한 20대 30대 버킷리스트 예시를 따라 하는 것이 아닌 진정 나다운 버킷리스트 목록을 작성해보았다. </p>,
# ...

# %%
wishlist2 = []
for num in range(7, 88):
    selector = f"#content > div > div.entry-content > div.contents_style > p:nth-child({num})"
    wish2 = soup.select_one(selector)
    if wish2:
        wishlist2.append({'위시목록':wish2.text})
        print(wish2.text)
# Out:
# - 정상 체중 유지하기
# - 마라톤 참여하기
# - 매일 기도 및 명상하기
# - 한달에 1권 이상 책 읽기
# - 아침 뉴스 보기
# - 뉴닉 정독하기
# - 블로그 공부하기
# - 둘째 블로그(수익형) 키우기
# - 영어 공부하기
# - 가족 여행 가기 (국내)
# - 행복적금 만기까지 깨지 않기
# - 고정 부수입 만들기
# - 헌혈하기
# - 유기견 입양센터 봉사 활동하기
# - 화장품 천연 제품으로 다 바꾸기
# - 가족 및 친구에게 편지쓰기
# - 북한산 둘레길 완주하기 (2020년 ~ing)
# - 해리포터 시리즈 전권 읽기 (2020년 ~ing)
# - 삼국지 전권 읽기 (2020년 ~ing)
# 20대 버킷리스트
#
#
# - 사진 및 카메라 공부하기
# - 동영상 편집 공부하기
# - 유튜브에 동영상 업로드하기 (일상 기록, 취미)
# - 외국어 배우기
# - 주업 외 새로운 수입 만들기 위한 (안정적인) 파이프라인 구축하기
# - 브런치 작가 도전하기
# - 워드프레스 도전하기
# - 이모티콘 만들어서 판매하기
# - 블로그 꾸준히 운영하기
# - 에어비앤비(airbnb) 운영해보기
# - 남의 집 프로젝트 : 호스트 되어 보기
# - 하우스메이트 구해서 월세 수익 벌어보기
# - 부수입으로 한 달에 1,000달러 이상 벌어보기
# - 부수입으로 컴퓨터 구입하기
# - 부수입으로 해외여행 가기
# - 국내여행 _ 안동
# - 국내여행 - 경주
# - 국내여행 _ 독도
# - 국내여행 _ 곡성
# - 국내여행 _ 담양
# - 두 번째 제주 한 달 살기 도전해보기 (서귀포시에서 살아보기)
# - 한라산 설경 보러 가기
# - 제주 올레길 완주하기
# - 제주도 오름 투어 하기 (안 가본 곳으로 10곳 이상)
# - 해외여행 _ 스위스
# - 해외여행 - 슬로베니아
# - 해외여행 _ 크로아티아
# - 해외여행 _ 쿠바
# - 서울에 내 집 마련하기
# - 홈카페 꾸미기
# - 홈오피스 꾸미기
# - 반려식물 키우기
# ...

# %%
wishlist2
# Out:
# [{'위시목록': '- 정상 체중 유지하기'},
#  {'위시목록': '- 마라톤 참여하기'},
#  {'위시목록': '- 매일 기도 및 명상하기'},
#  {'위시목록': '- 한달에 1권 이상 책 읽기'},
#  {'위시목록': '- 아침 뉴스 보기'},
#  {'위시목록': '- 뉴닉 정독하기'},
#  {'위시목록': '- 블로그 공부하기'},
#  {'위시목록': '- 둘째 블로그(수익형) 키우기'},
#  {'위시목록': '- 영어 공부하기'},
#  {'위시목록': '- 가족 여행 가기 (국내)'},
#  {'위시목록': '- 행복적금 만기까지 깨지 않기'},
#  {'위시목록': '- 고정 부수입 만들기'},
#  {'위시목록': '- 헌혈하기'},
#  {'위시목록': '- 유기견 입양센터 봉사 활동하기'},
#  {'위시목록': '- 화장품 천연 제품으로 다 바꾸기'},
#  {'위시목록': '- 가족 및 친구에게 편지쓰기'},
#  {'위시목록': '- 북한산 둘레길 완주하기 (2020년 ~ing)'},
#  {'위시목록': '- 해리포터 시리즈 전권 읽기\xa0(2020년 ~ing)'},
#  {'위시목록': '- 삼국지 전권 읽기\xa0(2020년 ~ing)'},
#  {'위시목록': '20대 버킷리스트\n\n'},
#  {'위시목록': '- 사진 및 카메라 공부하기'},
#  {'위시목록': '- 동영상 편집 공부하기'},
#  {'위시목록': '- 유튜브에 동영상 업로드하기 (일상 기록, 취미)'},
#  {'위시목록': '- 외국어 배우기'},
#  {'위시목록': '- 주업 외 새로운 수입 만들기 위한 (안정적인) 파이프라인 구축하기'},
#  {'위시목록': '- 브런치 작가 도전하기'},
#  {'위시목록': '- 워드프레스 도전하기'},
#  {'위시목록': '- 이모티콘 만들어서 판매하기'},
#  {'위시목록': '- 블로그 꾸준히 운영하기'},
#  {'위시목록': '- 에어비앤비(airbnb) 운영해보기'},
# ...

# %%
wishlist2_df = pd.DataFrame(wishlist2)

# %%
wishlist2_df
# Out:
#                                 위시목록
# 0                       - 정상 체중 유지하기
# 1                         - 마라톤 참여하기
# 2                     - 매일 기도 및 명상하기
# 3                   - 한달에 1권 이상 책 읽기
# 4                         - 아침 뉴스 보기
# ..                               ...
# 73               - 부모님 생신에 미역국 끓여드리기
# 74             - 다음 메인에 내 블로그 글 올려보기
# 75       - 부모님한테 자랑스러운 딸이 되기 위해 노력하기
# 76                  - 친구 결혼식에서 부케 받기
# 77  - 친구들이랑 브라이덜 샤워(Bridal Shower)하기
#
# [78 rows x 1 columns]

# %%
wishlist2_df.to_csv("./data/wish_list2.csv", index=False)

# %%
data2 = pd.read_csv("./data/wish_list2.csv")

# %%
data2
# Out:
#                                 위시목록
# 0                       - 정상 체중 유지하기
# 1                         - 마라톤 참여하기
# 2                     - 매일 기도 및 명상하기
# 3                   - 한달에 1권 이상 책 읽기
# 4                         - 아침 뉴스 보기
# ..                               ...
# 73               - 부모님 생신에 미역국 끓여드리기
# 74             - 다음 메인에 내 블로그 글 올려보기
# 75       - 부모님한테 자랑스러운 딸이 되기 위해 노력하기
# 76                  - 친구 결혼식에서 부케 받기
# 77  - 친구들이랑 브라이덜 샤워(Bridal Shower)하기
#
# [78 rows x 1 columns]

# %% [markdown]
# 세 번째 블로그 selenium도전

# %%
# selenium 4
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
import time

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.set_window_size(1920,1080)
driver.get("https://www.tiktok.com/@txtmoa0225/video/7311011998270049543")

# %%
page_html = driver.page_source

# %%
soup = bs(page_html, 'lxml')

# %%
soup.select_one('.css-xm2h10-PCommentText.e1g2efjf6').text
# Out:
# '헐 미⃫친⃫ 저 티니핑 진심녀인데 그 반지 구매처좀요 ㅜㅜ'

# %%
soup.select_one('.css-1i7ohvi-DivCommentItemContainer.eo72wou0 p').text
#main-content-video_detail > div > div.css-12kupwv-DivContentContainer.ege8lhx2 > div.css-1senhbu-DivLeftContainer.ege8lhx3 > div.css-x4xlc7-DivCommentContainer.e1a7v7ak0 > div.css-g6odvl-DivCommentContainer.ekjxngi0 > div
# Out:
# '헐 미⃫친⃫ 저 티니핑 진심녀인데 그 반지 구매처좀요 ㅜㅜ'

# %%
# 스크롤이벤트
snacks_for_beer = []
for page in range(2,11):
    print(f"{page}페이지")
    y = 0 # 마우스 스크롤 시작 지점
    y_step = 1000 # 마우스 스크롤 길이
    for i in range(1, 6):
        y =  y + y_step
        script = f"window.scrollTo({0},{y})"  # 자바 스크립트로 위치 지정
        driver.execute_script(script)         # 스크롤 실행
        time.sleep(2)
    page_html = driver.page_source 
    soup = BeautifulSoup(page_html, "lxml")
    snacks_for_beer.append(soup)
    driver.find_element(By.CSS_SELECTOR, f"#content > div.style_content__xWg5l > div.pagination_pagination__fsf34 > div > a:nth-child({page})").click() # 다음페이지 넘김 버튼 클릭
    time.sleep(2)

# %% [markdown]
# 시간이 부족해서 여기서 종료.

# %% [markdown]
# data1과 data2 병합

# %%
pd.merge(data2,data3, how="inner", on="PassengerId")
data = pd.merge(data,base_rate, how="inner", left_on="계약년월", right_on="기준금리년월")

data3.join(data2, how="inner", on="PassengerId")

# %%
# concat으로 합치기
data3 = pd.concat([data,data2], axis=1)

# %%
data3 #
# Out:
#                          위시목록              위시목록
# 0            1. 매일 10분씩 명상하기       - 정상 체중 유지하기
# 1         2. 새로운 언어 배우기 시작하기         - 마라톤 참여하기
# 2            3. 매주 한 권의 책 읽기     - 매일 기도 및 명상하기
# 3            4. 일기 쓰기 습관 들이기   - 한달에 1권 이상 책 읽기
# 4           5. 공개 연설 기술 개선하기         - 아침 뉴스 보기
# ..                        ...               ...
# 95  96. 대중교통 또는 자전거 이용 증가시키기                NaN
# 96         97. 환경 관련 교육 참여하기                NaN
# 97         98. 가정 내 물 사용 줄이기                NaN
# 98        99. 환경 보호 캠페인 참여하기                NaN
# 99   100. 제로 웨이스트 라이프스타일 추구하기               NaN
#
# [100 rows x 2 columns]

# %%
data4 = pd.concat([data,data2])

# %%
data4
# Out:
#                                 위시목록
# 0                   1. 매일 10분씩 명상하기
# 1                2. 새로운 언어 배우기 시작하기
# 2                   3. 매주 한 권의 책 읽기
# 3                   4. 일기 쓰기 습관 들이기
# 4                  5. 공개 연설 기술 개선하기
# ..                               ...
# 73               - 부모님 생신에 미역국 끓여드리기
# 74             - 다음 메인에 내 블로그 글 올려보기
# 75       - 부모님한테 자랑스러운 딸이 되기 위해 노력하기
# 76                  - 친구 결혼식에서 부케 받기
# 77  - 친구들이랑 브라이덜 샤워(Bridal Shower)하기
#
# [178 rows x 1 columns]

# %%
# merge로 합치기
data5 = pd.merge(data,data2, how='outer', on="위시목록")

# %%
data5.to_csv('./data/wish_final.csv', index=False)

# %%
# join은 불가능
data6 = data.join(data2, how="outer", on="위시목록")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data6 = data.join(data2, how="outer", on="위시목록")
#
# File ~\anaconda3\envs\testenv\lib\site-packages\pandas\core\frame.py:9729, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9566 def join(
#    9567     self,
#    9568     other: DataFrame | Series | Iterable[DataFrame | Series],
#    (...)
#    9574     validate: str | None = None,
#    9575 ) -> DataFrame:
#    9576     """
#    9577     Join columns of another DataFrame.
#    9578
#    (...)
#    9727     5  K1  A5   B1
#    9728     """
# -> 9729     return self._join_compat(
#    9730         other,
#    9731         on=on,
#    9732         how=how,
#    9733         lsuffix=lsuffix,
#    9734         rsuffix=rsuffix,
#    9735         sort=sort,
#    9736         validate=validate,
#    9737     )
#
# ...

# %%
data = pd.read_csv('./data/wish_final.csv')

# %%
data
# Out:
#                                  위시목록
# 0                    1. 매일 10분씩 명상하기
# 1                 2. 새로운 언어 배우기 시작하기
# 2                    3. 매주 한 권의 책 읽기
# 3                    4. 일기 쓰기 습관 들이기
# 4                   5. 공개 연설 기술 개선하기
# ..                                ...
# 173               - 부모님 생신에 미역국 끓여드리기
# 174             - 다음 메인에 내 블로그 글 올려보기
# 175       - 부모님한테 자랑스러운 딸이 되기 위해 노력하기
# 176                  - 친구 결혼식에서 부케 받기
# 177  - 친구들이랑 브라이덜 샤워(Bridal Shower)하기
#
# [178 rows x 1 columns]

# %%
# DataFrame의 '위시목록' column에 있는 값을 하나의 변수로 합치기
text_combined = ' '.join(data['위시목록'])

# %%
text_combined
# Out:
# '1. 매일 10분씩 명상하기  2. 새로운 언어 배우기 시작하기  3. 매주 한 권의 책 읽기  4. 일기 쓰기 습관 들이기  5. 공개 연설 기술 개선하기  6. 새로운 취미 시작하기  7. 자기계발 세미나 참여하기  8. 시간 관리 기술 향상시키기  9. 긍정적인 사고방식 유지하기  10. 매일 감사 일기 작성하기 11. 주 3회 이상 운동하기  12. 건강한 식습관 유지하기  13. 매일 8시간 수면 취하기  14. 스트레스 관리 방법 배우기  15. 요가나 명상 클래스 등록하기  16. 정기적으로 건강 검진 받기  17. 물 많이 마시기  18. 금연 또는 금주하기  19. 정기적인 스트레칭 습관 만들기  20. 건강한 간식 선택하기 21. 전문성 강화를 위한 추가 교육 받기  22. 효과적인 네트워킹 습관 만들기  23. 직장 내에서 리더십 역량 강화하기  24. 새로운 프로젝트나 업무에 도전하기  25. 직장 내 워크숍이나 팀 빌딩 참여하기  26. 시간 내서 직무 관련 서적 읽기  27. 멘토 찾기 또는 멘토 되기  28. 커리어 관련 목표 설정하고 달성하기  29. 효율적인 업무 방식 찾기  30. 직장 내 긍정적인 관계 구축하기 31. 가족과 더 많은 시간 보내기  32. 친구들과 정기적으로 만나기  33. 새로운 사람들과 친구 되기  34. 봉사 활동 참여하기  35. 지역 사회 이벤트에 참여하기  36. 관계 속에서 솔직하고 개방적이 되기  37. 갈등 해결 기술 향상시키기  38. 소셜 미디어 사용 줄이기  39. 친절하고 배려심 있는 사람 되기  40. 감사의 마음을 자주 표현하기 41. 여행 계획 세우기  42. 새로운 요리 레시피 시도하기  43. 사진 찍기  44. 정원 가꾸기  45. 음악 연주나 노래 배우기  46. 그림이나 공예 활동하기  47. 문화 행사나 전시회 방문하기  48. 캠핑이나 등산하기  49. 영화나 드라마 시리즈 즐기기  50. 블로그나 일기 작성하기 51. 예산 작성 및 관리하기  52. 저축 계획 세
# ...

# %% [markdown]
# 워드 클라우드로 시각화 해보자

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
font = 'C:/Windows/Fonts/H2GTRE.TTF'

wc = WordCloud(
    width = 600,
    height = 600,
    max_words=15000,
    font_path=font,
    background_color='white',
    stopwords=['새로운', '배우기', '내', '참여하기', '만들기','시작하기', '습관','향상시키기','관리','받기',
               '되기', '관련', '및', '이상', '매일']
).generate(str(text_combined))
plt.figure(figsize=(20,10))
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 599.5, 599.5, -0.5)
